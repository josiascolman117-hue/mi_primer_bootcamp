# %%
nombre = "Josias"
edad = 18
ciudad = "Capiata"
print(f'''{nombre}
{edad}
{ciudad}''')
# Out:
# Josias
# 18
# Capiata

# %%
cantidad_de_manzana = 4
cantidad_de_naranjas = 6
cantidad_de_frutas = cantidad_de_manzana + cantidad_de_naranjas
print(cantidad_de_frutas)
# Out:
# 10

# %%
#resta
cantidad_de_manzana = 6
cantidad_de_naranjas = 3
cantidad_de_frutas = cantidad_de_manzana - cantidad_de_naranjas
print(cantidad_de_frutas)
# Out:
# 3

# %%
nombre = "Sophia"
apellido = "Chena"
print("Hola Me llamo Josias Colman Un Gusto")
print(nombre+ " " +apellido)
# Out:
# Hola Me llamo Josias Colman Un Gusto
# Sophia Chena

# %%
total_de_caramelos  = int(input("cual es la cantidad de caramelos"))
niños = int(input("Para cuantos niños son los caramelos"))
caremelos_por_niño = total_de _caramelos // niños
# Out:
#   Cell In[9], line 3
#     caremelos_por_niño = total_de _caramelos // niños
#                                   ^
# SyntaxError: invalid syntax

# %%
def saludo  ():
    nombre1 = (input("ingrese su nombre"))
    apellido1 = (input("ingrese su apellido"))
    edad1 = (input("ingrese su edad"))
    print(f"Hola mi nombre es {nombre1} {apellido1} {edad1}")

saludo()
saludo()
saludo()
# Out:
# Hola mi nombre es josias colman 18
# Hola mi nombre es sophia chena 17
# Hola mi nombre es sophia monte 18

# %%
combo_rapi = input("ingrese su pedido")
bebida_de_su_preferencia = input("ingrese sabor de su bebida")
aderezo1 = input("ingrese que aderezo ")

def combo_rapi1 (combo, bebida, aderezo):
    print ("su pedido se esta preparando...")
    print(f''' su pedido esta saliendo
         
          {combo} 
          {bebida} 
          {aderezo}''')
    
    
    

combo_rapi1(combo_rapi, bebida_de_su_preferencia, aderezo1)
# Out:
# su pedido se esta preparando...
#  su pedido esta saliendo
#
#           cajita feliz
#           agua
#           sin absolutamente nada

# %%
impuesto = 0.1
def calcular_total():
    introduce_el_producto_adquirir = ("introduzca el producto")
    calcular_iva = 0.1
    precio_total_del_producto = introduce_el_producto_adquirir + impuesto
    print(f'el precio total {precio_total_del_producto} ' )

    calcular_total():
